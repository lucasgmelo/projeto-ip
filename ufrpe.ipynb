# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv(
    'SUP_ALUNO_2019.csv',
    encoding = "ISO-8859-1", 
    usecols=['CO_IES', 'TP_COR_RACA'],
    sep='|'
    )

data.head()
# Out:
#    CO_IES  TP_COR_RACA
# 0       1            2
# 1       1            3
# 2       1            3
# 3       1            2
# 4       1            3

# %% [markdown]
# ---
# # Visualização de dados na UFRPE

# %%
num_of_stds = data.loc[data['CO_IES'] == 587].count()[0]
print(num_of_stds)
# Out:
# 18643

# %% [markdown]
# ## Utilizando o código IES da UFRPE verificamos que 18643 alunos foram registrados

# %%
stds = data.loc[data['CO_IES'] == 587]

B = stds.loc[stds['TP_COR_RACA'] == 1].count()[0]
P = stds.loc[stds['TP_COR_RACA'] == 2].count()[0]
Pa = stds.loc[stds['TP_COR_RACA'] == 3].count()[0]
A = stds.loc[stds['TP_COR_RACA'] == 4].count()[0]
In = stds.loc[stds['TP_COR_RACA'] == 5].count()[0]

no_info = num_of_stds - (B+ P+ Pa+ A +In)

x_axis = ['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'sem dados']
y_axis = [B, P , Pa, A, In, no_info]

plt.bar(x_axis, y_axis, width=0.7)
plt.show()

# %% [markdown]
# ### Distribuição por raça/cor na UFRPE

# %%
df = pd.read_csv(
    'SUP_ALUNO_2019.csv',
    encoding = "ISO-8859-1", 
    usecols=['CO_IES', 'TP_SEXO', 'CO_CURSO', 'TP_COR_RACA'],
    sep='|'
)

cod_uni = 587
cod_BCC = 1102628

stds_ufrpe = df.loc[df['CO_IES'] == cod_uni]
stds_BCC = stds_ufrpe.loc[stds_ufrpe['CO_CURSO'] == cod_BCC] #Dataframe dos estudantes de computação na rural

mns = stds_BCC.loc[stds_BCC['TP_SEXO'] == 2].count()[0]
wms = stds_BCC.loc[stds_BCC['TP_SEXO'] == 1].count()[0]

plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Homens', 'Mulheres')
y_pos = np.arange(len(people))
performance = [mns , wms]

ax.barh(y_pos, performance, align='center', color='r')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis() 
ax.set_xlabel('Quantidade')
ax.set_title('Distribuição homens/mulheres')

plt.show()

# %% [markdown]
# ## Distribuição por gênero no curso de Bacharelado em Ciência da Computação na UFRPE

# %%
cod_med_vet = 14507

stds_med_vet = stds_ufrpe.loc[stds_ufrpe['CO_CURSO'] == cod_med_vet] #Dataframe estudantes medicina veterinária

mens = stds_med_vet.loc[stds_med_vet['TP_SEXO'] == 2].count()[0]
womens = stds_med_vet.loc[stds_med_vet['TP_SEXO'] == 1].count()[0]

plt.rcdefaults()
fig, ax = plt.subplots()

people = ('Homens', 'Mulheres')
y_pos = np.arange(len(people))
performance = [mens , womens]

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis() 
ax.set_xlabel('Quantidade')
ax.set_title('Distribuição homens/mulheres')

plt.show()

# %% [markdown]
# ## Distribuição por gênero no curso de Medicina Veterinária na UFRPE
